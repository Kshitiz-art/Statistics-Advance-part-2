# %% [markdown]
# QUE 1 What is hypothesis testing in statistics
#
# Ans Hypothesis testing is a statistical method used to make inferences or decisions about a population based on sample data. It involves making an assumption (null hypothesis) and testing whether sample data supports or contradicts it.

# %% [markdown]
# QUE 2 What is the null hypothesis, and how does it differ from the alternative hypothesis
#
# Ans Null Hypothesis (Ho): The default assumption that there is no effect, difference, or relationship in the population.
#
# 2. Alternative Hypothesis (Ha): The opposing assumption that there is an effect, difference, or relationship.

# %% [markdown]
# QUE 3 What is the significance level in hypothesis testing, and why is it important
#
# Ans The significance level is the probability of rejecting the null hypothesis when it is true. It is typically set at 0.05 (5%) or 0.01(1%)and determines the threshold for statistical significance.

# %% [markdown]
# QUE 4 What does a P-value represent in hypothesis testing
#
# Ans The P-value measures the probability of obtaining the observed results (or more extreme) if the null hypothesis is true.

# %% [markdown]
# QUE 5 How do you interpret the P-value in hypothesis testing
#
# Ans 1  P-value < α: Reject Ho  (statistically significant)
#
# 2. P-value > α: Fail to reject
# 𝐻
# 0
# H
# 0
# ​
#   (not statistically significant)

# %% [markdown]
# QUE 6 What are Type 1 and Type 2 errors in hypothesis testing
#
# Ans Type I Error (False Positive): Rejecting
# 𝐻
# 0
# H
# 0
# ​
#   when it is actually true.
#
# Type II Error (False Negative): Failing to reject
# 𝐻
# 0
# H
# 0
# ​
#   when it is actually false

# %% [markdown]
# QUE 7 What is the difference between a one-tailed and a two-tailed test in hypothesis testing
# Ans One-Tailed Test: Tests if the effect is only in one direction (e.g., greater or less).
#
# Two-Tailed Test: Tests for an effect in both directions (e.g., different but not specified as greater or less).

# %% [markdown]
# QUE 8 What is the Z-test, and when is it used in hypothesis testing
#
# Ans A Z-test is used when the population variance is known and the sample size is large (n > 30 ) It is used to test means and proportions.

# %% [markdown]
# QUE 9 How do you calculate the Z-score, and what does it represent in hypothesis testing
#
# Ans Z=
# σ
# X−μ
# ​

# %% [markdown]
# QUE 10 What is the T-distribution, and when should it be used instead of the normal distribution
#
# Ans The T-distribution is used when the population variance is unknown and the sample size is small (
# 𝑛
# <
# 30
# n<30). It accounts for the extra variability due to small samples.

# %% [markdown]
# QUE 11 What is the difference between a Z-test and a T-test
#
# Ans Z-Test: Used for large samples and when population variance is known.
#
# T-Test: Used for small samples and when population variance is unknown.

# %% [markdown]
# QUE 12 What is the T-test, and how is it used in hypothesis testing
#
# Ans  T-test is a statistical test used to determine if there is a significant difference between the means of two groups. It is commonly applied in hypothesis testing when the sample size is small and the population standard deviation is unknown. It comes in three types: one-sample, independent two-sample, and paired T-tests.

# %% [markdown]
# QUE 13 What is the relationship between Z-test and T-test in hypothesis testing
#
# Ans The Z-test and T-test both assess differences in population parameters using sample data. They differ based on sample size and known information:
#
# 1. Z-test is used for larger sample sizes and when the population variance is known.
# 2. T-test is used for smaller sample sizes and when the population variance is unknown, relying on the T-distribution.

# %% [markdown]
# QUE 14  What is a confidence interval, and how is it used to interpret statistical results
#
# Ans A confidence interval provides a range of values in which a population parameter is likely to fall, based on a sample statistic. For example, a 95% confidence interval means there is a 95% chance the true parameter lies within the interval. It helps quantify uncertainty in statistical results.

# %% [markdown]
# QUE 15 What is the margin of error, and how does it affect the confidence interval
#
# Ans The margin of error represents the extent to which the sample result could differ from the true population value. A smaller margin of error results in a narrower confidence interval, indicating greater precision. It is influenced by factors like sample size and variability.

# %% [markdown]
# QUE 16 How is Bayes' Theorem used in statistics, and what is its significance
#
# Ans Bayes' Theorem calculates the probability of an event based on prior knowledge of related conditions. It’s significant in fields such as medical testing, machine learning, and decision-making by updating probabilities as new information is obtained

# %% [markdown]
# QUE 17  What is the Chi-square distribution, and when is it used
#
# Ans The Chi-square distribution is a statistical distribution used for tests involving categorical data. It's applied in scenarios like goodness-of-fit tests, contingency tables, and variance analysis to evaluate independence or goodness of fit.

# %% [markdown]
# QUE 18 What is the Chi-square goodness of fit test, and how is it applied
#
# AnsThis test evaluates whether observed categorical data matches an expected distribution. It’s applied by calculating the Chi-square statistic, comparing it to a critical value, and determining whether differences are significant.

# %% [markdown]
# QUE 19 What is the F-distribution, and when is it used in hypothesis testing
#
# Ans The F-distribution is used in hypothesis testing, particularly in comparing variances between two groups or in analysis of variance (ANOVA). It assesses whether the variability among groups is significantly different.

# %% [markdown]
# QUE 20  What is an ANOVA test, and what are its assumptions
#
# Ans ANOVA (Analysis of Variance) tests whether there are significant differences between the means of three or more groups. Assumptions include:
#
# 1.Independence of observations.
# 2. Normally distributed populations.
# 3. Equal variances across groups (homoscedasticity).

# %% [markdown]
# QUE 21 What are the different types of ANOVA tests
#
# Ans The main types include:
# 1. One-way ANOVA: Analyzes one independent variable with multiple levels.
# 2. Two-way ANOVA: Considers two independent variables.
# 3. Repeated measures ANOVA: Evaluates data where subjects are measured multiple times.

# %% [markdown]
#  QUE 22 What is the F-test, and how does it relate to hypothesis testing
#
#  Ans The F-test compares variances of two datasets and determines if they are significantly different. It is pivotal in ANOVA and regression analysis to test hypotheses regarding the equality of variances or overall model fit.

# %% [markdown]
# **PRATICAL QUESTION**
#
# ---

# %% [markdown]
# QUE 1 Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and
# interpret the results

# %%
def z_test(sample, pop_mean, pop_std, alpha=0.05):
    n = len(sample)
    sample_mean = np.mean(sample)
    z_score = (sample_mean - pop_mean) / (pop_std / np.sqrt(n))
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

    result = "Reject null hypothesis" if p_value < alpha else "Fail to reject null hypothesis"
    return z_score, p_value, result

# %% [markdown]
# QUE 2 Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python

# %%
import numpy as np
from scipy.stats import ttest_ind

# Simulate random data
np.random.seed(42)  # Set seed for reproducibility
group1 = np.random.normal(loc=50, scale=10, size=100)  # Mean=50, StdDev=10, Size=100
group2 = np.random.normal(loc=55, scale=10, size=100)  # Mean=55, StdDev=10, Size=100

# Perform two-sample t-test
t_statistic, p_value = ttest_ind(group1, group2)

# Print the results
print("T-statistic:", t_statistic)
print("P-value:", p_value)

# Interpret results
alpha = 0.05  # Significance level
if p_value < alpha:
    print("Reject the null hypothesis: Significant difference between groups")
else:
    print("Fail to reject the null hypothesis: No significant difference between groups")
# Out:
# T-statistic: -4.7546959435052765
# P-value: 3.8191352626795345e-06
# Reject the null hypothesis: Significant difference between groups

# %% [markdown]
# QUE 3 Implement a one-sample Z-test using Python to compare the sample mean with the population mean

# %%
import numpy as np
from scipy.stats import norm

# Sample data
sample = [52, 55, 50, 53, 54, 56, 58, 51, 53, 57]  # Replace with your sample data
sample_mean = np.mean(sample)  # Calculate sample mean
sample_std = np.std(sample, ddof=1)  # Calculate sample standard deviation
n = len(sample)  # Sample size

# Population parameters
population_mean = 50  # Specify population mean
alpha = 0.05  # Significance level

# Calculate the Z statistic
z_statistic = (sample_mean - population_mean) / (sample_std / np.sqrt(n))

# Calculate p-value (two-tailed test)
p_value = 2 * (1 - norm.cdf(abs(z_statistic)))

# Print the results
print("Z-statistic:", z_statistic)
print("P-value:", p_value)

# Interpretation
if p_value < alpha:
    print("Reject the null hypothesis: Significant difference between sample mean and population mean")
else:
    print("Fail to reject the null hypothesis: No significant difference between sample mean and population mean")
# Out:
# Z-statistic: 4.74107925606768
# P-value: 2.1258274609525785e-06
# Reject the null hypothesis: Significant difference between sample mean and population mean

# %% [markdown]
# QUE 4  Perform a two-tailed Z-test using Python and visualize the decision region on a plot

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Sample data
sample = [52, 55, 50, 53, 54, 56, 58, 51, 53, 57]  # Replace with your sample data
sample_mean = np.mean(sample)  # Calculate sample mean
sample_std = np.std(sample, ddof=1)  # Calculate sample standard deviation
n = len(sample)  # Sample size

# Population parameters
population_mean = 50  # Specify population mean
alpha = 0.05  # Significance level

# Calculate Z-statistic
z_statistic = (sample_mean - population_mean) / (sample_std / np.sqrt(n))

# Calculate critical values for two-tailed test
z_critical = norm.ppf(1 - alpha / 2)

# Visualize decision region
z_values = np.linspace(-4, 4, 500)  # Range of Z-values for visualization
pdf_values = norm.pdf(z_values)  # Probability density function of standard normal distribution

plt.figure(figsize=(8, 6))
plt.plot(z_values, pdf_values, label='Standard Normal Distribution')
plt.fill_between(z_values, pdf_values, where=(z_values < -z_critical) | (z_values > z_critical),
                 color='red', alpha=0.4, label='Rejection Region')
plt.axvline(z_statistic, color='blue', linestyle='--', label=f'Z-statistic: {z_statistic:.2f}')
plt.axvline(-z_critical, color='green', linestyle='--', label=f'Critical Value (-Z): {-z_critical:.2f}')
plt.axvline(z_critical, color='green', linestyle='--', label=f'Critical Value (+Z): {z_critical:.2f}')
plt.title('Two-Tailed Z-Test Decision Region')
plt.xlabel('Z-value')
plt.ylabel('Probability Density')
plt.legend(loc='upper right')
plt.grid()
plt.show()

# Calculate P-value for two-tailed test
p_value = 2 * (1 - norm.cdf(abs(z_statistic)))

# Print results
print("Z-statistic:", z_statistic)
print("P-value:", p_value)

# Interpretation
if p_value < alpha:
    print("Reject the null hypothesis: Significant difference between sample mean and population mean")
else:
    print("Fail to reject the null hypothesis: No significant difference between sample mean and population mean")
# Out:
# Z-statistic: 4.74107925606768
# P-value: 2.1258274609525785e-06
# Reject the null hypothesis: Significant difference between sample mean and population mean

# %% [markdown]
# QUE 5 Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def visualize_errors(mu0, mu1, sigma, n, alpha):
    """
    Visualizes Type 1 and Type 2 errors in hypothesis testing.

    Parameters:
        mu0: Population mean under null hypothesis
        mu1: Alternative population mean
        sigma: Standard deviation of the population
        n: Sample size
        alpha: Significance level
    """
    # Calculate the standard error
    std_err = sigma / np.sqrt(n)

    # Critical value for Type 1 error
    z_critical = norm.ppf(1 - alpha)
    critical_value = mu0 + z_critical * std_err

    # Calculate the probability of Type 2 error (Beta)
    beta = norm.cdf(critical_value, loc=mu1, scale=std_err)

    # Visualization
    x = np.linspace(mu0 - 4 * std_err, mu1 + 4 * std_err, 1000)
    null_dist = norm.pdf(x, loc=mu0, scale=std_err)
    alt_dist = norm.pdf(x, loc=mu1, scale=std_err)

    plt.figure(figsize=(10, 6))
    plt.plot(x, null_dist, label="Null Hypothesis ($H_0$)", color="blue")
    plt.plot(x, alt_dist, label="Alternative Hypothesis ($H_a$)", color="red")
    plt.axvline(critical_value, color="green", linestyle="--", label="Critical Value")
    plt.fill_between(x, null_dist, where=(x > critical_value), color="blue", alpha=0.3, label="Type 1 Error (α)")
    plt.fill_between(x, alt_dist, where=(x <= critical_value), color="red", alpha=0.3, label="Type 2 Error (β)")
    plt.title("Type 1 (α) and Type 2 (β) Errors in Hypothesis Testing")
    plt.xlabel("Sample Mean")
    plt.ylabel("Probability Density")
    plt.legend(loc="upper right")
    plt.grid()
    plt.show()

    # Print errors
    print("Type 1 Error (α):", alpha)
    print("Type 2 Error (β):", beta)

# Example usage
visualize_errors(mu0=50, mu1=55, sigma=10, n=30, alpha=0.05)
# Out:
# Type 1 Error (α): 0.05
# Type 2 Error (β): 0.1370303099357847

# %% [markdown]
# QUE 6  Write a Python program to perform an independent T-test and interpret the results

# %%
import numpy as np
from scipy.stats import ttest_ind

# Generate sample data for two independent groups
np.random.seed(42)
group1 = np.random.normal(loc=50, scale=10, size=30)
group2 = np.random.normal(loc=55, scale=10, size=30)

# Perform independent T-test
t_stat, p_value = ttest_ind(group1, group2)

# Print results
print("T-statistic:", t_stat)
print("P-value:", p_value)

# Interpretation
alpha = 0.05  # Significance level
if p_value < alpha:
    print("Reject the null hypothesis: Significant difference between the two groups")
else:
    print("Fail to reject the null hypothesis: No significant difference between the two groups")
# Out:
# T-statistic: -2.3981151520102415
# P-value: 0.019717941865758228
# Reject the null hypothesis: Significant difference between the two groups

# %% [markdown]
# QUE 7 Perform a paired sample T-test using Python and visualize the comparison results

# %%
import numpy as np
from scipy.stats import ttest_rel
import matplotlib.pyplot as plt

# Generate paired sample data (before and after treatment)
np.random.seed(42)
before = np.random.normal(loc=50, scale=10, size=30)
after = before + np.random.normal(loc=5, scale=5, size=30)  # Simulate improvement

# Perform paired T-test
t_stat, p_value = ttest_rel(before, after)

# Print results
print("T-statistic:", t_stat)
print("P-value:", p_value)

# Interpretation
alpha = 0.05  # Significance level
if p_value < alpha:
    print("Reject the null hypothesis: Significant difference between paired samples")
else:
    print("Fail to reject the null hypothesis: No significant difference between paired samples")

# Visualization
plt.figure(figsize=(8, 6))
plt.scatter(range(len(before)), before, label="Before", color="blue")
plt.scatter(range(len(after)), after, label="After", color="red")
plt.plot(range(len(before)), before, color="blue", linestyle="--", alpha=0.5)
plt.plot(range(len(after)), after, color="red", linestyle="--", alpha=0.5)
plt.title("Paired Sample Comparison")
plt.xlabel("Sample Index")
plt.ylabel("Value")
plt.legend()
plt.grid()
plt.show()
# Out:
# T-statistic: -5.1697777164235825
# P-value: 1.5823343932441755e-05
# Reject the null hypothesis: Significant difference between paired samples

# %% [markdown]
# QUE 8 Simulate data and perform both Z-test and T-test, then compare the results using Python

# %%
import numpy as np
from scipy.stats import norm, ttest_1samp

# Simulate random data
np.random.seed(42)
sample = np.random.normal(loc=50, scale=10, size=30)  # Sample from a normal distribution
population_mean = 55  # Population mean to test against

# Perform Z-test
sample_mean = np.mean(sample)
sample_std = np.std(sample, ddof=1)
z_statistic = (sample_mean - population_mean) / (sample_std / np.sqrt(len(sample)))
p_value_z = 2 * (1 - norm.cdf(abs(z_statistic)))  # Two-tailed test

# Perform T-test
t_statistic, p_value_t = ttest_1samp(sample, population_mean)

# Compare results
print("Z-Test:")
print(f"Z-statistic: {z_statistic:.2f}, P-value: {p_value_z:.4f}")

print("\nT-Test:")
print(f"T-statistic: {t_statistic:.2f}, P-value: {p_value_t:.4f}")

# Interpret findings
if p_value_z < 0.05:
    print("\nZ-Test: Reject the null hypothesis (significant difference).")
else:
    print("\nZ-Test: Fail to reject the null hypothesis (no significant difference).")

if p_value_t < 0.05:
    print("T-Test: Reject the null hypothesis (significant difference).")
else:
    print("T-Test: Fail to reject the null hypothesis (no significant difference).")
# Out:
# Z-Test:
# Z-statistic: -4.19, P-value: 0.0000
#
# T-Test:
# T-statistic: -4.19, P-value: 0.0002
#
# Z-Test: Reject the null hypothesis (significant difference).
# T-Test: Reject the null hypothesis (significant difference).

# %% [markdown]
# QUE 9 Write a Python function to calculate the confidence interval for a sample mean and explain its significance

# %%
import numpy as np
from scipy.stats import norm

def calculate_confidence_interval(sample, confidence_level):
    """
    Calculates the confidence interval for the sample mean.

    Parameters:
        sample: List or array of sample data
        confidence_level: Confidence level (e.g., 0.95 for 95%)

    Returns:
        Tuple: (lower_bound, upper_bound)
    """
    sample_mean = np.mean(sample)
    sample_std = np.std(sample, ddof=1)
    n = len(sample)

    # Calculate margin of error
    z_critical = norm.ppf((1 + confidence_level) / 2)  # Two-tailed critical Z-value
    margin_of_error = z_critical * (sample_std / np.sqrt(n))

    # Confidence interval
    lower_bound = sample_mean - margin_of_error
    upper_bound = sample_mean + margin_of_error

    return lower_bound, upper_bound

# Example usage
sample_data = [52, 55, 50, 53, 54, 56, 58, 51, 53, 57]
confidence_interval = calculate_confidence_interval(sample_data, 0.95)
print("Confidence Interval (95%):", confidence_interval)
# Out:
# Confidence Interval (95%): (np.float64(52.28773850280534), np.float64(55.51226149719466))

# %% [markdown]
# QUE 10 Write a Python program to calculate the margin of error for a given confidence level using sample data

# %%
import numpy as np
from scipy.stats import norm

def calculate_margin_of_error(sample, confidence_level):
    """
    Calculates the margin of error for a sample mean.

    Parameters:
        sample: List or array of sample data
        confidence_level: Confidence level (e.g., 0.95 for 95%)

    Returns:
        Margin of Error
    """
    sample_std = np.std(sample, ddof=1)
    n = len(sample)

    # Calculate margin of error
    z_critical = norm.ppf((1 + confidence_level) / 2)  # Two-tailed critical Z-value
    margin_of_error = z_critical * (sample_std / np.sqrt(n))

    return margin_of_error

# Example usage
sample_data = [52, 55, 50, 53, 54, 56, 58, 51, 53, 57]
margin_of_error = calculate_margin_of_error(sample_data, 0.95)
print("Margin of Error (95% Confidence Level):", margin_of_error)
# Out:
# Margin of Error (95% Confidence Level): 1.612261497194657

# %% [markdown]
# QUE 11 Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process

# %%
def bayesian_inference(prior, likelihood, evidence):
    """
    Calculates posterior probability using Bayes' Theorem.

    Parameters:
        prior: Prior probability of the hypothesis
        likelihood: Likelihood of the evidence given the hypothesis
        evidence: Total probability of the evidence

    Returns:
        Posterior probability
    """
    posterior = (prior * likelihood) / evidence
    return posterior

# Example usage
prior = 0.3  # Prior probability of hypothesis
likelihood = 0.8  # Likelihood of evidence given hypothesis
evidence = 0.5  # Total probability of evidence

posterior = bayesian_inference(prior, likelihood, evidence)
print("Posterior Probability:", posterior)
# Out:
# Posterior Probability: 0.48

# %% [markdown]
# QUE 12 Perform a Chi-square test for independence between two categorical variables in Python

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# Example data (contingency table)
data = {
    'Category A': [20, 15, 25],
    'Category B': [30, 25, 20]
}
df = pd.DataFrame(data, index=['Group 1', 'Group 2', 'Group 3'])

# Perform Chi-square test
chi2, p, dof, expected = chi2_contingency(df)

# Results
print("Chi-square statistic:", chi2)
print("P-value:", p)
print("Degrees of freedom:", dof)
print("Expected frequencies:")
print(expected)

# Interpretation
alpha = 0.05
if p < alpha:
    print("\nReject the null hypothesis: The variables are dependent.")
else:
    print("\nFail to reject the null hypothesis: The variables are independent.")
# Out:
# Chi-square statistic: 3.4312500000000004
# P-value: 0.17985127852950905
# Degrees of freedom: 2
# Expected frequencies:
# [[22.22222222 27.77777778]
#  [17.77777778 22.22222222]
#  [20.         25.        ]]
#
# Fail to reject the null hypothesis: The variables are independent.

# %% [markdown]
# QUE 13 Write a Python program to calculate the expected frequencies for a Chi-square test based on observed
# data

# %%
import numpy as np

def calculate_expected_frequencies(observed):
    """
    Calculates expected frequencies for Chi-square test.

    Parameters:
        observed: 2D array of observed frequencies (contingency table)

    Returns:
        Expected frequencies as a 2D array
    """
    row_totals = np.sum(observed, axis=1)
    col_totals = np.sum(observed, axis=0)
    grand_total = np.sum(observed)

    expected = np.outer(row_totals, col_totals) / grand_total
    return expected

# Example usage
observed = np.array([[20, 30], [15, 25], [25, 20]])
expected = calculate_expected_frequencies(observed)
print("Expected Frequencies:")
print(expected)
# Out:
# Expected Frequencies:
# [[22.22222222 27.77777778]
#  [17.77777778 22.22222222]
#  [20.         25.        ]]

# %% [markdown]
# QUE 14  Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution

# %%
from scipy.stats import chisquare

# Observed data
observed = [50, 30, 20]

# Expected distribution
expected = [40, 40, 20]

# Perform goodness-of-fit test
chi2, p = chisquare(f_obs=observed, f_exp=expected)

# Results
print("Chi-square statistic:", chi2)
print("P-value:", p)

# Interpretation
alpha = 0.05
if p < alpha:
    print("Reject the null hypothesis: Observed data does not fit the expected distribution.")
else:
    print("Fail to reject the null hypothesis: Observed data fits the expected distribution.")
# Out:
# Chi-square statistic: 5.0
# P-value: 0.0820849986238988
# Fail to reject the null hypothesis: Observed data fits the expected distribution.

# %% [markdown]
# QUE 15 Create a Python script to simulate and visualize the Chi-square distribution and discuss its characteristics

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import chi2

def visualize_chi_square_distribution(df):
    """
    Simulates and visualizes Chi-square distribution for given degrees of freedom.
    """
    x = np.linspace(0, 20, 1000)
    y = chi2.pdf(x, df)

    plt.figure(figsize=(8, 6))
    plt.plot(x, y, label=f"Chi-square Distribution (df={df})", color="blue")
    plt.title("Chi-square Distribution")
    plt.xlabel("Chi-square Value")
    plt.ylabel("Probability Density")
    plt.grid()
    plt.legend()
    plt.show()

# Example usage
visualize_chi_square_distribution(df=4)

# %% [markdown]
# QUE 16  Implement an F-test using Python to compare the variances of two random samples

# %%
import numpy as np
from scipy.stats import f

# Generate sample data
np.random.seed(42)
group1 = np.random.normal(loc=50, scale=10, size=30)
group2 = np.random.normal(loc=55, scale=15, size=30)

# Calculate variances
var1 = np.var(group1, ddof=1)
var2 = np.var(group2, ddof=1)

# F-test statistic
f_statistic = var1 / var2

# Degrees of freedom
df1 = len(group1) - 1
df2 = len(group2) - 1

# P-value (two-tailed test)
p_value = 2 * min(f.cdf(f_statistic, df1, df2), 1 - f.cdf(f_statistic, df1, df2))

# Results
print("F-statistic:", f_statistic)
print("P-value:", p_value)

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: Variances are significantly different.")
else:
    print("Fail to reject the null hypothesis: Variances are not significantly different.")
# Out:
# F-statistic: 0.41525416799961246
# P-value: 0.02087559545078621
# Reject the null hypothesis: Variances are significantly different.

# %% [markdown]
# QUE 17 Write a Python program to perform an ANOVA test to compare means between multiple groups and
# interpret the results

# %%
from scipy.stats import f_oneway

# Example data: Three groups with sample data
group1 = [20, 22, 19, 24, 25]
group2 = [28, 30, 32, 29, 31]
group3 = [25, 27, 26, 24, 28]

# Perform one-way ANOVA
f_statistic, p_value = f_oneway(group1, group2, group3)

# Results
print("F-statistic:", f_statistic)
print("P-value:", p_value)

# Interpretation
alpha = 0.05  # Significance level
if p_value < alpha:
    print("Reject the null hypothesis: At least one group mean is significantly different.")
else:
    print("Fail to reject the null hypothesis: No significant difference between group means.")
# Out:
# F-statistic: 20.869565217391305
# P-value: 0.00012397772646166892
# Reject the null hypothesis: At least one group mean is significantly different.

# %% [markdown]
# QUE 18 Perform a one-way ANOVA test using Python to compare the means of different groups and plot the results

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import f_oneway

# Example data
data = {'Group': ['A', 'A', 'A', 'A', 'A', 'B', 'B', 'B', 'B', 'B', 'C', 'C', 'C', 'C', 'C'],
        'Value': [20, 22, 19, 24, 25, 28, 30, 32, 29, 31, 25, 27, 26, 24, 28]}
df = pd.DataFrame(data)

# Perform one-way ANOVA
group_data = [df[df['Group'] == g]['Value'] for g in df['Group'].unique()]
f_statistic, p_value = f_oneway(*group_data)

# Print results
print("F-statistic:", f_statistic)
print("P-value:", p_value)

# Plot using seaborn
sns.boxplot(x='Group', y='Value', data=df)
plt.title("Comparison of Group Means")
plt.grid()
plt.show()
# Out:
# F-statistic: 20.869565217391305
# P-value: 0.00012397772646166892

# %% [markdown]
# QUE 19 Write a Python function to check the assumptions (normality, independence, and equal variance) for ANOVA

# %%
from scipy.stats import shapiro, levene

def check_anova_assumptions(data):
    """
    Checks the assumptions for ANOVA:
    1. Normality
    2. Equal variance
    3. Independence is assumed in the design of the experiment.

    Parameters:
        data: Dictionary of groups and their values.
    """
    # Normality test for each group
    for group, values in data.items():
        stat, p = shapiro(values)
        print(f"Shapiro-Wilk Test for Group {group}: p-value = {p:.4f}")
        if p < 0.05:
            print(f"Group {group} fails the normality test.")
        else:
            print(f"Group {group} passes the normality test.")

    # Equal variance test (Levene's test)
    values_list = list(data.values())
    stat, p = levene(*values_list)
    print(f"\nLevene's Test for Equal Variance: p-value = {p:.4f}")
    if p < 0.05:
        print("Groups fail the equal variance test.")
    else:
        print("Groups pass the equal variance test.")

# Example data
data = {'Group A': [20, 22, 19, 24, 25], 'Group B': [28, 30, 32, 29, 31], 'Group C': [25, 27, 26, 24, 28]}
check_anova_assumptions(data)
# Out:
# Shapiro-Wilk Test for Group Group A: p-value = 0.6919
# Group Group A passes the normality test.
# Shapiro-Wilk Test for Group Group B: p-value = 0.9672
# Group Group B passes the normality test.
# Shapiro-Wilk Test for Group Group C: p-value = 0.9672
# Group Group C passes the normality test.
#
# Levene's Test for Equal Variance: p-value = 0.3632
# Groups pass the equal variance test.

# %% [markdown]
# QUE 20 Perform a two-way ANOVA test using Python to study the interaction between two factors and visualize the
# results

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
import matplotlib.pyplot as plt
import seaborn as sns

# Example data
data = pd.DataFrame({
    'Factor1': ['A', 'A', 'A', 'B', 'B', 'B', 'C', 'C', 'C'] * 2,
    'Factor2': ['X', 'X', 'X', 'Y', 'Y', 'Y', 'Z', 'Z', 'Z'] * 2,
    'Value': [22, 23, 21, 25, 27, 24, 28, 26, 29, 20, 22, 18, 24, 25, 23, 27, 30, 26]
})

# Two-way ANOVA
model = ols('Value ~ C(Factor1) + C(Factor2) + C(Factor1):C(Factor2)', data=data).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(anova_table)

# Visualization
sns.boxplot(x='Factor1', y='Value', hue='Factor2', data=data)
plt.title("Two-way ANOVA: Group Comparisons")
plt.grid()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 2, but rank is 0
#   warnings.warn('covariance of constraints does not have full '
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:1923: RuntimeWarning: invalid value encountered in divide
#   F /= J
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 2, but rank is 0
#   warnings.warn('covariance of constraints does not have full '
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 2
#   warnings.warn('covariance of constraints does not have full '
#                            sum_sq    df          F    PR(>F)
# ...

# %% [markdown]
# QUE 21 Write a Python program to visualize the F-distribution and discuss its use in hypothesis testing

# %%
import numpy as np
from scipy.stats import f
import matplotlib.pyplot as plt

def plot_f_distribution(df1, df2):
    """
    Visualizes F-distribution for given degrees of freedom.
    """
    x = np.linspace(0, 5, 500)
    y = f.pdf(x, df1, df2)

    plt.figure(figsize=(8, 6))
    plt.plot(x, y, label=f"F-Distribution (df1={df1}, df2={df2})")
    plt.title("F-Distribution")
    plt.xlabel("F-Statistic")
    plt.ylabel("Probability Density")
    plt.grid()
    plt.legend()
    plt.show()

# Example usage
plot_f_distribution(df1=5, df2=10)

# %% [markdown]
# QUE 22 Perform a one-way ANOVA test in Python and visualize the results with boxplots to compare group means

# %%
import pandas as pd
from scipy.stats import f_oneway
import seaborn as sns
import matplotlib.pyplot as plt

# Example data
data = {'Group': ['A'] * 5 + ['B'] * 5 + ['C'] * 5,
        'Value': [20, 22, 19, 24, 25, 28, 30, 32, 29, 31, 25, 27, 26, 24, 28]}
df = pd.DataFrame(data)

# Perform one-way ANOVA
group_data = [df[df['Group'] == g]['Value'] for g in df['Group'].unique()]
f_statistic, p_value = f_oneway(*group_data)

# Print results
print("F-statistic:", f_statistic)
print("P-value:", p_value)

# Visualization
sns.boxplot(x='Group', y='Value', data=df)
plt.title("Comparison of Group Means (One-Way ANOVA)")
plt.grid()
plt.show()
# Out:
# F-statistic: 20.869565217391305
# P-value: 0.00012397772646166892

# %% [markdown]
# QUE 23 Simulate random data from a normal distribution, then perform hypothesis testing to evaluate the means

# %%
import numpy as np
from scipy.stats import ttest_1samp

# Simulate random data
np.random.seed(42)
sample = np.random.normal(loc=50, scale=5, size=30)  # Mean=50, StdDev=5, Size=30

# Perform one-sample t-test
population_mean = 50
t_statistic, p_value = ttest_1samp(sample, population_mean)

# Print results
print("T-statistic:", t_statistic)
print("P-value:", p_value)

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: The sample mean is significantly different from the population mean.")
else:
    print("Fail to reject the null hypothesis: No significant difference from the population mean.")
# Out:
# T-statistic: -1.1450173670383355
# P-value: 0.26156414618801277
# Fail to reject the null hypothesis: No significant difference from the population mean.

# %% [markdown]
# QUE 24 Perform a hypothesis test for population variance using a Chi-square distribution and interpret the results

# %%
from scipy.stats import chi2

# Sample data
np.random.seed(42)
sample = np.random.normal(loc=50, scale=5, size=30)
sample_variance = np.var(sample, ddof=1)

# Population parameters
population_variance = 25  # Hypothesized variance

# Chi-square statistic
n = len(sample)
chi_square_statistic = (n - 1) * sample_variance / population_variance

# Calculate p-value (two-tailed test)
p_value = 2 * min(chi2.cdf(chi_square_statistic, df=n-1),
                  1 - chi2.cdf(chi_square_statistic, df=n-1))

# Results
print("Chi-square Statistic:", chi_square_statistic)
print("P-value:", p_value)

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: The population variance is significantly different.")
else:
    print("Fail to reject the null hypothesis: No significant difference in population variance.")
# Out:
# Chi-square Statistic: 23.4903355116039
# P-value: 0.4927181645162759
# Fail to reject the null hypothesis: No significant difference in population variance.

# %% [markdown]
# QUE 25 Write a Python script to perform a Z-test for comparing proportions between two datasets or groups

# %%
import statsmodels.stats.proportion as prop

# Example data
success_a, trials_a = 30, 100
success_b, trials_b = 40, 120

# Perform two-proportion Z-test
stat, p_value = prop.proportions_ztest([success_a, success_b], [trials_a, trials_b])

# Results
print("Z-statistic:", stat)
print("P-value:", p_value)

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: The proportions are significantly different.")
else:
    print("Fail to reject the null hypothesis: No significant difference in proportions.")
# Out:
# Z-statistic: -0.5285499781147278
# P-value: 0.5971176684141065
# Fail to reject the null hypothesis: No significant difference in proportions.

# %% [markdown]
# QUE 26  Implement an F-test for comparing the variances of two datasets, then interpret and visualize the results

# %%
import matplotlib.pyplot as plt
from scipy.stats import f

# Generate sample data
np.random.seed(42)
group1 = np.random.normal(loc=50, scale=10, size=30)
group2 = np.random.normal(loc=55, scale=15, size=30)

# Calculate variances
var1 = np.var(group1, ddof=1)
var2 = np.var(group2, ddof=1)

# F-test statistic
f_statistic = var1 / var2

# Degrees of freedom
df1 = len(group1) - 1
df2 = len(group2) - 1

# P-value (two-tailed test)
p_value = 2 * min(f.cdf(f_statistic, df1, df2), 1 - f.cdf(f_statistic, df1, df2))

# Results
print("F-statistic:", f_statistic)
print("P-value:", p_value)

# Visualization of variances
plt.boxplot([group1, group2], labels=["Group 1", "Group 2"])
plt.title("Comparison of Group Variances")
plt.ylabel("Values")
plt.grid()
plt.show()
# Out:
# F-statistic: 0.41525416799961246
# P-value: 0.02087559545078621
# <ipython-input-10-ec1124be7558>:28: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([group1, group2], labels=["Group 1", "Group 2"])

# %% [markdown]
# QUE 27 Perform a Chi-square test for goodness of fit with simulated data and analyze the results

# %%
from scipy.stats import chisquare

# Simulated data (observed frequencies)
observed = [50, 30, 20]
expected = [40, 40, 20]  # Expected frequencies

# Perform goodness-of-fit test
chi2_statistic, p_value = chisquare(f_obs=observed, f_exp=expected)

# Results
print("Chi-square Statistic:", chi2_statistic)
print("P-value:", p_value)

# Interpretation
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: The observed data does not fit the expected distribution.")
else:
    print("Fail to reject the null hypothesis: The observed data fits the expected distribution.")
# Out:
# Chi-square Statistic: 5.0
# P-value: 0.0820849986238988
# Fail to reject the null hypothesis: The observed data fits the expected distribution.
